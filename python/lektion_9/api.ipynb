# %% [markdown]
# API

# %% [markdown]
# ## VI använder extension thunder client

# %% [markdown]
# Vad är en API?
#
# en bred term. Men vi prata om
# REST - API:er
# hur man hämta data. Om man är på en hemsida, eller göra data analys i python, hämtar man data från ett api.
#
#
# ## CRUD
# CREATE, READ, UPDATE, DELETE
#
# ## REST
#
# REST - POST, GET, PUT, DELETE
#
# Vad är REST?
#
# en REST API är en API där vi skickar requests till en API och den svarar. Så enkelt
# Interface att prata med database och få in data till våra datorer
#
#
# API:er returnerar data i olika format. Oftast JSON, äldre har XML
# ## JSON, XML, TEXT
#
# Finns väldig många publika api:er
#
#
# ## Processen
#
# - Gå till url
# - skickar en GET request
#     - egentligen är en webbsida en get requeset.
#         - då hämtar man HTML
#     - men när vi använder API:er hämtar vi JSON istället.
#
# här är JSON raw data
#
# ![image.png](attachment:image.png)
#
# här är hur JSON ser ut
#
# ![image.png](attachment:image-2.png)
